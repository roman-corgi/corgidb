# %%
from UI import ReferenceStarPickerUI
import corgidb.ingest
eng = corgidb.ingest.gen_engine('plandb_user', 'plandb_scratch')

ui = ReferenceStarPickerUI(engine=eng)
ui.display()
# Out:
# VBox(children=(HTML(value="<h2 style='color:#1565c0;margin-bottom:4px'>&#128301; Reference Star Picker</h2><p …
